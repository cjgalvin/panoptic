# %% [markdown]
# # Mask R-CNN Demo
#
# ## File modified by Casey Galvin to perform panoptic segmentation of Cityscapes validation dataset
# ## Modified section starts where noted below
#
# A quick intro to using the pre-trained model to detect and segment objects.

# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt

# Root directory of the project
ROOT_DIR = os.path.abspath("../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
# Import COCO config
sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
import coco

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
#if not os.path.exists(COCO_MODEL_PATH):
#    utils.download_trained_weights(COCO_MODEL_PATH)

# Directory of images to run detection on
IMAGE_DIR = os.path.join(ROOT_DIR, "images")
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Configurations
#
# We'll be using a model trained on the MS-COCO dataset. The configurations of this model are in the ```CocoConfig``` class in ```coco.py```.
#
# For inferencing, modify the configurations a bit to fit the task. To do so, sub-class the ```CocoConfig``` class and override the attributes you need to change.

# %%
class InferenceConfig(coco.CocoConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Create Model and Load Trained Weights

# %%
# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)

# Load weights trained on MS-COCO
model.load_weights(COCO_MODEL_PATH, by_name=True)
# Out:
# WARNING:tensorflow:From C:\Users\andor.neo\Anaconda3\envs\TFenv\lib\site-packages\tensorflow\python\ops\sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.

# %% [markdown]
# ## Class Names
#
# The model classifies objects and returns class IDs, which are integer value that identify each class. Some datasets assign integer values to their classes and some don't. For example, in the MS-COCO dataset, the 'person' class is 1 and 'teddy bear' is 88. The IDs are often sequential, but not always. The COCO dataset, for example, has classes associated with class IDs 70 and 72, but not 71.
#
# To improve consistency, and to support training on data from multiple sources at the same time, our ```Dataset``` class assigns it's own sequential integer IDs to each class. For example, if you load the COCO dataset using our ```Dataset``` class, the 'person' class would get class ID = 1 (just like COCO) and the 'teddy bear' class is 78 (different from COCO). Keep that in mind when mapping class IDs to class names.
#
# To get the list of class names, you'd load the dataset and then use the ```class_names``` property like this.
# ```
# # Load COCO dataset
# dataset = coco.CocoDataset()
# dataset.load_coco(COCO_DIR, "train")
# dataset.prepare()
#
# # Print class names
# print(dataset.class_names)
# ```
#
# We don't want to require you to download the COCO dataset just to run this demo, so we're including the list of class names below. The index of the class name in the list represent its ID (first class is 0, second is 1, third is 2, ...etc.)

# %%
# COCO Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']

# %% [markdown]
# ## Run Object Detection

# %%
from skimage.transform import rescale, resize
import matplotlib.pyplot as plt

# %% [markdown]
# ## Pipeline to produce panoptic segmentations and calculate panoptic quality metric
# ### Instance segmentation performed using Mask R-CNN implementation (Matterport)
# ### Semantic segmentation files produced by Deeplab V3+ (Google)
# #### Work below this line by Casey Galvin, building on Mask R-CNN implementation above

# %% [markdown]
# ### Cityscapes label information taken from Deeplab V3+ semantic segmentation implementation

# %%
from __future__ import print_function, absolute_import, division
from PIL import Image

from collections import namedtuple





#--------------------------------------------------------------------------------

# Definitions

#--------------------------------------------------------------------------------



# a label and all meta information

Label = namedtuple( 'Label' , [



    'name'        , # The identifier of this label, e.g. 'car', 'person', ... .

                    # We use them to uniquely name a class



    'id'          , # An integer ID that is associated with this label.

                    # The IDs are used to represent the label in ground truth images

                    # An ID of -1 means that this label does not have an ID and thus

                    # is ignored when creating ground truth images (e.g. license plate).

                    # Do not modify these IDs, since exactly these IDs are expected by the

                    # evaluation server.



    'trainId'     , # Feel free to modify these IDs as suitable for your method. Then create

                    # ground truth images with train IDs, using the tools provided in the

                    # 'preparation' folder. However, make sure to validate or submit results

                    # to our evaluation server using the regular IDs above!

                    # For trainIds, multiple labels might have the same ID. Then, these labels

                    # are mapped to the same class in the ground truth images. For the inverse

                    # mapping, we use the label that is defined first in the list below.

                    # For example, mapping all void-type classes to the same ID in training,

                    # might make sense for some approaches.

                    # Max value is 255!



    'category'    , # The name of the category that this label belongs to



    'categoryId'  , # The ID of this category. Used to create ground truth images

                    # on category level.



    'hasInstances', # Whether this label distinguishes between single instances or not



    'ignoreInEval', # Whether pixels having this class as ground truth label are ignored

                    # during evaluations or not



    'color'       , # The color of this label

    ] )





#--------------------------------------------------------------------------------

# A list of all labels

#--------------------------------------------------------------------------------



# Please adapt the train IDs as appropriate for your approach.

# Note that you might want to ignore labels with ID 255 during training.

# Further note that the current train IDs are only a suggestion. You can use whatever you like.

# Make sure to provide your results using the original IDs and not the training IDs.

# Note that many IDs are ignored in evaluation and thus you never need to predict these!



labels = [

    #       name                     id    trainId   category            catId     hasInstances   ignoreInEval   color

    Label(  'unlabeled'            ,  0 ,      255 , 'void'            , 0       , False        , True         , (  0,  0,  0) ),

    Label(  'ego vehicle'          ,  1 ,      255 , 'void'            , 0       , False        , True         , (  0,  0,  0) ),

    Label(  'rectification border' ,  2 ,      255 , 'void'            , 0       , False        , True         , (  0,  0,  0) ),

    Label(  'out of roi'           ,  3 ,      255 , 'void'            , 0       , False        , True         , (  0,  0,  0) ),

    Label(  'static'               ,  4 ,      255 , 'void'            , 0       , False        , True         , (  0,  0,  0) ),

    Label(  'dynamic'              ,  5 ,      255 , 'void'            , 0       , False        , True         , (111, 74,  0) ),

    Label(  'ground'               ,  6 ,      255 , 'void'            , 0       , False        , True         , ( 81,  0, 81) ),

    Label(  'road'                 ,  7 ,        0 , 'flat'            , 1       , False        , False        , (128, 64,128) ),

    Label(  'sidewalk'             ,  8 ,        1 , 'flat'            , 1       , False        , False        , (244, 35,232) ),

    Label(  'parking'              ,  9 ,      255 , 'flat'            , 1       , False        , True         , (250,170,160) ),

    Label(  'rail track'           , 10 ,      255 , 'flat'            , 1       , False        , True         , (230,150,140) ),

    Label(  'building'             , 11 ,        2 , 'construction'    , 2       , False        , False        , ( 70, 70, 70) ),

    Label(  'wall'                 , 12 ,        3 , 'construction'    , 2       , False        , False        , (102,102,156) ),

    Label(  'fence'                , 13 ,        4 , 'construction'    , 2       , False        , False        , (190,153,153) ),

    Label(  'guard rail'           , 14 ,      255 , 'construction'    , 2       , False        , True         , (180,165,180) ),

    Label(  'bridge'               , 15 ,      255 , 'construction'    , 2       , False        , True         , (150,100,100) ),

    Label(  'tunnel'               , 16 ,      255 , 'construction'    , 2       , False        , True         , (150,120, 90) ),

    Label(  'pole'                 , 17 ,        5 , 'object'          , 3       , False        , False        , (153,153,153) ),

    Label(  'polegroup'            , 18 ,      255 , 'object'          , 3       , False        , True         , (153,153,153) ),

    Label(  'traffic light'        , 19 ,        6 , 'object'          , 3       , False        , False        , (250,170, 30) ),

    Label(  'traffic sign'         , 20 ,        7 , 'object'          , 3       , False        , False        , (220,220,  0) ),

    Label(  'vegetation'           , 21 ,        8 , 'nature'          , 4       , False        , False        , (107,142, 35) ),

    Label(  'terrain'              , 22 ,        9 , 'nature'          , 4       , False        , False        , (152,251,152) ),

    Label(  'sky'                  , 23 ,       10 , 'sky'             , 5       , False        , False        , ( 70,130,180) ),

    Label(  'person'               , 24 ,       11 , 'human'           , 6       , True         , False        , (220, 20, 60) ),

    Label(  'rider'                , 25 ,       12 , 'human'           , 6       , True         , False        , (255,  0,  0) ),

    Label(  'car'                  , 26 ,       13 , 'vehicle'         , 7       , True         , False        , (  0,  0,142) ),

    Label(  'truck'                , 27 ,       14 , 'vehicle'         , 7       , True         , False        , (  0,  0, 70) ),

    Label(  'bus'                  , 28 ,       15 , 'vehicle'         , 7       , True         , False        , (  0, 60,100) ),

    Label(  'caravan'              , 29 ,      255 , 'vehicle'         , 7       , True         , True         , (  0,  0, 90) ),

    Label(  'trailer'              , 30 ,      255 , 'vehicle'         , 7       , True         , True         , (  0,  0,110) ),

    Label(  'train'                , 31 ,       16 , 'vehicle'         , 7       , True         , False        , (  0, 80,100) ),

    Label(  'motorcycle'           , 32 ,       17 , 'vehicle'         , 7       , True         , False        , (  0,  0,230) ),

    Label(  'bicycle'              , 33 ,       18 , 'vehicle'         , 7       , True         , False        , (119, 11, 32) ),

    Label(  'license plate'        , -1 ,       -1 , 'vehicle'         , 7       , False        , True         , (  0,  0,142) ),

]





#--------------------------------------------------------------------------------

# Create dictionaries for a fast lookup

#--------------------------------------------------------------------------------



# Please refer to the main method below for example usages!



# name to label object

name2label      = { label.name    : label for label in labels           }

# id to label object

id2label        = { label.id      : label for label in labels           }

# trainId to label object

trainId2label   = { label.trainId : label for label in reversed(labels) }

# category to list of label objects

category2labels = {}

for label in labels:

    category = label.category

    if category in category2labels:

        category2labels[category].append(label)

    else:

        category2labels[category] = [label]



#--------------------------------------------------------------------------------

# Assure single instance name

#--------------------------------------------------------------------------------



# returns the label name that describes a single instance (if possible)

# e.g.     input     |   output

#        ----------------------

#          car       |   car

#          cargroup  |   car

#          foo       |   None

#          foogroup  |   None

#          skygroup  |   None

def assureSingleInstanceName( name ):

    # if the name is known, it is not a group

    if name in name2label:

        return name

    # test if the name actually denotes a group

    if not name.endswith("group"):

        return None

    # remove group

    name = name[:-len("group")]

    # test if the new name exists

    if not name in name2label:

        return None

    # test if the new name denotes a label that actually has instances

    if not name2label[name].hasInstances:

        return None

    # all good then

    return name

# %%
######
# 
# Computes IoU between instance and semantic segmentations
# Used to determine if classification matches between segmantations
# 
# Arguments:
# ins_results is results array from Mask R-CNN instance segmentation (r variable output in instance segmentation model)
# ins is specific instance being analyzed
# sem_seg is semantic segmentation result from Deeplab
# city_id is Cityscapes ID for object corresponding to ins
#
# Returns:
# IoU for object corresponding to ins in ins_results
#
######

def ins_sem_compare(ins_results, ins, sem_seg, city_id):
    
    #define roi for instance and semantic comparison
    roi = ins_results['rois'][ins]
    
    y1 = roi[0]
    x1 = roi[1]
    y2 = roi[2]
    x2 = roi[3]  
    
    #Cast sem_seg to binary mask
    sem_seg_binary = sem_seg[y1:y2,x1:x2] == city_id
    
    #find intersection between instance and semantic segmentation
    #only looks in instance ROI
    intersection_map = np.logical_and(r['masks'][:, :, ins][y1:y2,x1:x2], sem_seg_binary)
    
    intersection = np.sum(intersection_map)
    
    #find union, including subtracting intersection to avoid double counting
    union = np.sum(ins_results['masks'][:,:,ins]) + np.sum(sem_seg_binary) - intersection
    
    #calculate intersection over union
    iou = intersection/union
    
    return iou

# %%
######
# 
# Converts COCO ids (MASK R-CNN objects in Matterport implementation) to Cityscapes ids (Deeplab semantic segmentation)
# Needed to match output of segmentation from the two outputs
#
# Arguments:
# coco_id is ID of an object using the COCO dataset nomenclature
# 
# Returns:
# city_id is ID of input object using the Cityscapes nomenclature
#
######

def coco2city(coco_id):
    object_class = class_names[coco_id]
    city_id = name2label[object_class].id
    return city_id

# %%
######
#
# Produces colors for panoptic segmentation map
# Shades different instances of the same class a different color
#
# Arguments:
# pan_seg is panoptic segmentation with object labels
#
# Returns:
# colored_pan_seg is colored panoptic segmentation map
# cmap is color map information to plot or save using Matplotlib
#
######

def pan_colors(pan_seg):
    
    import colorsys
    import matplotlib.colors

    colors = []

    for pan_id in np.unique(pan_seg):

        if pan_id > 999: #multiplication factor to create enumerated instances

            classId = int(pan_id/1000)
            objectint = pan_id - classId*1000

            labelcolor = id2label[classId].color

            hls_color = colorsys.rgb_to_hls(labelcolor[0], labelcolor[1], labelcolor[2])
            newcolor = [hls_color[0], (1 - objectint/len(np.unique(pan_seg))) * hls_color[1], hls_color[2]]

            color = colorsys.hls_to_rgb(newcolor[0], newcolor[1], newcolor[2])

        else:
            color = id2label[pan_id].color

        norm_color = [need2norm/255 for need2norm in color]

        colors.append(norm_color)

    cmap = matplotlib.colors.ListedColormap(colors)

    norm = matplotlib.colors.BoundaryNorm(np.arange(len(np.unique(pan_seg))+1)-0.5, len(colors))
    
    u, ind = np.unique(pan_seg, return_inverse=True)
    
    colored_pan_seg = np.reshape(ind, pan_seg.shape)
    
    return colored_pan_seg, cmap
        
    #plt.figure(figsize=(15,30))
    #plt.imshow(b, cmap=cmap, norm=norm, shape=[1024, 2048])
    #plt.axis("off")

# %%
######
#
# Function that combines semantic segmentation and instance segmentations using heuristics
# 
# Arguments:
# ins_results is results array from Mask R-CNN instance segmentation (r variable output in instance segmentation model)
# sem_seg is semantic segmentation result from Deeplab
#
# Returns:
# pan_map is panoptic segmentation output with class labels (Cityscapes nomenclature)
# pan_map_color is panoptic segmentation output colored according to pan_colors function
# cmap is color map produced by pan_colors function used for plotting and saving pan_map_color with Matplotlib functions
#
######

def create_pan_seg(ins_results, sem_seg):
    #This follows the heuristic of the panoptic segmentation paper
    
    #Create a copy of the semantic segmentation to overwrite instances
    #Casts sem_seg into int32 to accommodate enumerated class_ids
    pan_map = sem_seg.astype(int).copy()
    
    #Stores coco2city translation and class_id enumerations
    inst_dict = {}
    
    #List of class_ids to mark void for remaining semantic labels
    markvoid = []
    
    #For each instance in the instance segmentations...
    for ins, obj_id in enumerate(ins_results['class_ids']):
        
        #Possible improvement:
        #If instance segmentation confidence is low, don't use
        
        #Translate COCO to Cityscapes class_ids for current object
        try:
            city_id = coco2city(obj_id)
        except KeyError:
            print("Found an object I am not trained to handle:", obj_id)
            continue
            
        
        #Compare instance and semantic prediction
        #If results do not agree, mark void
        iou = ins_sem_compare(ins_results, ins, sem_seg, city_id)
        
        if iou < 0.5:
            
            #Mark pixels as void
            pan_map[np.nonzero(ins_results['masks'][:,:,ins])] = 0
            
        else:
            
            #Get current enumeration of object
            inst_int = inst_dict.get(city_id, 0)
            
            #Transform city_id to instance_id --> Follows Cityscapes convention of 5 digit number: first 2 digits are class_id, last 3 are enumerated instance
            inst_id = city_id*1000 + inst_int
            
            #Enumerate city_id to the next instance
            inst_dict[city_id] = inst_int + 1
            
            #Append ID to mark void for remaining semantic pixels
            if inst_int == 0:
                markvoid.append(city_id)

            #Write instance ID onto panoptic map
            pan_map[np.nonzero(ins_results['masks'][:,:,ins])] = inst_id
    
    #Void remaining semantic pixels for enumerated objects
    for void in markvoid:
        pan_map[pan_map == void] = 0
    
    #Void remaining semantic pixels that fall below a critical abundance threshold
    #Define critical area factor --> can be adjusted
    void_factor = 1/pan_map.shape[1]
    
    for void in np.unique(pan_map):
        
        #Compare size of IDs and mark void if smaller than void_factor
        if np.sum(pan_map == void)/pan_map.size < void_factor:
            pan_map[pan_map == void] = 0
    
    #plt.imshow(pan_map, cmap='hot')
    pan_map_color, cmap = pan_colors(pan_map)
        
    return pan_map, pan_map_color, cmap

# %%
######
#
# Function to calculate IoU between panoptic segmentation and ground truth files
# 
# Arguments:
# pan_seg is panoptic segmentation with object labels
# ground_truth is ground truth file from Cityscapes dataset (instance segmentation, using XXYYY format, where XX is label and YYY is enumerated instance)
# class_id is Cityscapes class ID from pan_seg
# matched_id is instance segmentation ID that has been matched with class ID (XX is same between images, however YYY can be different for same instance)
#
# Returns:
# iou is intersection over union for pan_seg and ground_truth
#
######

def calc_iou(pan_seg, ground_truth, class_id, matched_id):
    
    intersection = np.sum((pan_seg == class_id) & (ground_truth == matched_id))
    
    union = np.sum((pan_seg == class_id) | (ground_truth == matched_id))
    
    iou = intersection/union
    
    return iou

######
#
# Function to calculate panoptic quality metric (and segmentation and recognition qualities) between panoptic segmentation and ground truth files
# 
# Arguments:
# pan_seg is panoptic segmentation with object labels
# ground_truth is ground truth file from Cityscapes dataset (instance segmentation, using XXYYY format, where XX is label and YYY is enumerated instance)
#
# Returns:
# seg_qual is segment quality (average IoU over true positives)
# rec_qual is recognition quality (F1 score)
# pan_qual is panoptic quality (seg_qual * rec_qual)
#
######

def calc_pq(pan_seg, ground_truth):
    
    from scipy import stats 
    
    iou_match = []
    fp_ids = []
    fn_ids = []
    results_list = []
    
    for class_id in np.unique(pan_seg):

        if class_id == 0:
            continue

        if class_id > 999: #factor for enumeration

            #match likely instance IDs based on mode over class ID in overlapping pixels
            matched_id = stats.mode(ground_truth[pan_seg == class_id], axis=None)[0][0]
            occurs = stats.mode(ground_truth[pan_seg == class_id], axis=None)[1][0]

        else:

            #For stuff IDs, class_id and matched_id will be equal (no individual instances)
            matched_id = class_id

        iou = calc_iou(pan_seg, ground_truth, class_id, matched_id)

        #print(class_id, iou)
        
        if iou < 0.5:
            fp_ids.append(class_id)
            
            if class_id in np.unique(ground_truth):
                fn_ids.append(class_id)
                
            continue

        iou_match.append(iou)


    tp = len(iou_match)
    fp = len(fp_ids)
    fn = len(fn_ids)
        
    seg_qual = np.sum(iou_match)/len(iou_match)
    
    rec_qual = tp/(tp + 0.5*fp + 0.5*fn)
    
    pan_qual = seg_qual * rec_qual
    
    #print("sq =", seg_qual, "rq =", rec_qual)
    #print("pq =", pan_qual)
    #print("True positives:", tp)
    #print("False positives:", fp)
    #print("False negatives:", fn)
    
    return seg_qual, rec_qual, pan_qual

# %% [markdown]
# ## Pipeline to analyze all images from Cityscapes validation set and save necessary information

# %%
#Pipeline to analyze all images and save necessary information

from os import listdir
from os.path import isfile, join

#Load ground truth image file names
val_dir = r"C:\Users\andor.neo\Desktop\casey\ml_ai\models-master\research\deeplab\datasets\cityscapes\gtFine\val"
cities = os.listdir(val_dir)

gt_files = []
for city in cities:
    gt_files.extend([city + "\\" + f for f in listdir(val_dir + "\\" + city) if "instanceIds" in f])

print("Loaded ground truth file locations...")
    
#Semantic segmentation image locations
img_dir = r'C:\Users\andor.neo\Desktop\casey\ml_ai\models-master\research\deeplab\datasets\cityscapes\exp\train_on_train_set\vis\segmentation_results'
raw_dir = r'C:\Users\andor.neo\Desktop\casey\ml_ai\models-master\research\deeplab\datasets\cityscapes\exp\train_on_train_set\vis\raw_segmentation_results'

sem_str = '_prediction.png'
raw_str = '_raw.png'
image_str = '_image.png'

print("Loaded semantic segmentation file locations...")

#Directory for saving panoptic segmentation results
pan_dir = r'C:\Users\andor.neo\Desktop\casey\ml_ai\models-master\research\deeplab\datasets\cityscapes\exp\train_on_train_set\vis\panoptic_results'
pan_str = '_panoptic.png'

#Results lists
sq = []
rq = []
pq = []

print("Starting panoptic segmentation routine...")
#Create panoptic segmentation and return panoptic quality score for images
for i in range(0, len(gt_files)):
    num_str = str(i).zfill(6)
    
    sem_file = '\\' + num_str + sem_str
    image_file = '\\' + num_str + image_str
    raw_file = '\\' + num_str + raw_str
    
    image = skimage.io.imread(img_dir + image_file)

    # Run detection
    results = model.detect([image], verbose=0)
    r = results[0]
    print('Processed image', num_str)
    
    # Loading semantic segmentation images
    sem_img = Image.open(img_dir + sem_file)
    sem_array = np.array(sem_img)
    raw_sem = Image.open(raw_dir + raw_file)
    raw_sem_array = np.array(raw_sem)
    
    # Create panoptic segmentation from semantic and object segmentations using heuristics
    pan_seg, pan_seg_color, cmap = create_pan_seg(r, raw_sem_array)
    print("Made panoptic segmentation for image", num_str)
    
    #Ground truth images
    gt_image = Image.open(val_dir + "\\" + gt_files[i])
    gt_array = np.array(gt_image)
    
    # Analyze panoptic segmentation relative to ground truth (pan_city_ins_arr)
    seg_qual, rec_qual, pan_qual = calc_pq(pan_seg, gt_array)
    
    # Append results to master lists for analysis
    sq.append(seg_qual)
    rq.append(rec_qual)
    pq.append(pan_qual)
    
    # Save resulting panoptic segmentation images with indexed colors
    pan_file = '\\' + num_str + pan_str
    plt.imsave(pan_dir + pan_file, pan_seg_color, cmap=cmap)
    
    print("Analyzed and saved panoptic segmentation for image", num_str)
# Out:
# Loaded ground truth file locations...
# Loaded semantic segmentation file locations...
# Starting panoptic segmentation routine...
# Processed image 000000
# Made panoptic segmentation for image 000000
# Analyzed and saved panoptic segmentation for image 000000
# Processed image 000001
# Made panoptic segmentation for image 000001
# Analyzed and saved panoptic segmentation for image 000001
# Processed image 000002
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000002
# Analyzed and saved panoptic segmentation for image 000002
# Processed image 000003
# Found an object I am not trained to handle: 39
# Made panoptic segmentation for image 000003
# Analyzed and saved panoptic segmentation for image 000003
# Processed image 000004
# Made panoptic segmentation for image 000004
# Analyzed and saved panoptic segmentation for image 000004
# Processed image 000005
# Made panoptic segmentation for image 000005
# Analyzed and saved panoptic segmentation for image 000005
# Processed image 000006
# Made panoptic segmentation for image 000006
# Analyzed and saved panoptic segmentation for image 000006
# Processed image 000007
# Made panoptic segmentation for image 000007
# Analyzed and saved panoptic segmentation for image 000007
# Processed image 000008
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000008
# Analyzed and saved panoptic segmentation for image 000008
# Processed image 000009
# Made panoptic segmentation for image 000009
# Analyzed and saved panoptic segmentation for image 000009
# Processed image 000010
# Made panoptic segmentation for image 000010
# Analyzed and saved panoptic segmentation for image 000010
# Processed image 000011
# Made panoptic segmentation for image 000011
# Analyzed and saved panoptic segmentation for image 000011
# Processed image 000012
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000012
# Analyzed and saved panoptic segmentation for image 000012
# Processed image 000013
# Made panoptic segmentation for image 000013
# Analyzed and saved panoptic segmentation for image 000013
# Processed image 000014
# Made panoptic segmentation for image 000014
# Analyzed and saved panoptic segmentation for image 000014
# Processed image 000015
# Made panoptic segmentation for image 000015
# Analyzed and saved panoptic segmentation for image 000015
# Processed image 000016
# Made panoptic segmentation for image 000016
# Analyzed and saved panoptic segmentation for image 000016
# Processed image 000017
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000017
# Analyzed and saved panoptic segmentation for image 000017
# Processed image 000018
# Made panoptic segmentation for image 000018
# Analyzed and saved panoptic segmentation for image 000018
# Processed image 000019
# Made panoptic segmentation for image 000019
# Analyzed and saved panoptic segmentation for image 000019
# Processed image 000020
# Made panoptic segmentation for image 000020
# Analyzed and saved panoptic segmentation for image 000020
# Processed image 000021
# Made panoptic segmentation for image 000021
# Analyzed and saved panoptic segmentation for image 000021
# Processed image 000022
# Found an object I am not trained to handle: 33
# Made panoptic segmentation for image 000022
# Analyzed and saved panoptic segmentation for image 000022
# Processed image 000023
# Found an object I am not trained to handle: 13
# Made panoptic segmentation for image 000023
# Analyzed and saved panoptic segmentation for image 000023
# Processed image 000024
# Made panoptic segmentation for image 000024
# Analyzed and saved panoptic segmentation for image 000024
# Processed image 000025
# Found an object I am not trained to handle: 75
# Made panoptic segmentation for image 000025
# Analyzed and saved panoptic segmentation for image 000025
# Processed image 000026
# Made panoptic segmentation for image 000026
# Analyzed and saved panoptic segmentation for image 000026
# Processed image 000027
# Made panoptic segmentation for image 000027
# Analyzed and saved panoptic segmentation for image 000027
# Processed image 000028
# Made panoptic segmentation for image 000028
# Analyzed and saved panoptic segmentation for image 000028
# Processed image 000029
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000029
# Analyzed and saved panoptic segmentation for image 000029
# Processed image 000030
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000030
# Analyzed and saved panoptic segmentation for image 000030
# Processed image 000031
# Made panoptic segmentation for image 000031
# Analyzed and saved panoptic segmentation for image 000031
# Processed image 000032
# Made panoptic segmentation for image 000032
# Analyzed and saved panoptic segmentation for image 000032
# Processed image 000033
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000033
# Analyzed and saved panoptic segmentation for image 000033
# Processed image 000034
# Found an object I am not trained to handle: 25
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000034
# Analyzed and saved panoptic segmentation for image 000034
# Processed image 000035
# Made panoptic segmentation for image 000035
# Analyzed and saved panoptic segmentation for image 000035
# Processed image 000036
# Found an object I am not trained to handle: 57
# Made panoptic segmentation for image 000036
# Analyzed and saved panoptic segmentation for image 000036
# Processed image 000037
# Made panoptic segmentation for image 000037
# Analyzed and saved panoptic segmentation for image 000037
# Processed image 000038
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000038
# Analyzed and saved panoptic segmentation for image 000038
# Processed image 000039
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000039
# Analyzed and saved panoptic segmentation for image 000039
# Processed image 000040
# Made panoptic segmentation for image 000040
# Analyzed and saved panoptic segmentation for image 000040
# Processed image 000041
# Made panoptic segmentation for image 000041
# Analyzed and saved panoptic segmentation for image 000041
# Processed image 000042
# Made panoptic segmentation for image 000042
# Analyzed and saved panoptic segmentation for image 000042
# Processed image 000043
# Made panoptic segmentation for image 000043
# Analyzed and saved panoptic segmentation for image 000043
# Processed image 000044
# Made panoptic segmentation for image 000044
# Analyzed and saved panoptic segmentation for image 000044
# Processed image 000045
# Made panoptic segmentation for image 000045
# Analyzed and saved panoptic segmentation for image 000045
# Processed image 000046
# Found an object I am not trained to handle: 14
# Found an object I am not trained to handle: 75
# Made panoptic segmentation for image 000046
# Analyzed and saved panoptic segmentation for image 000046
# Processed image 000047
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000047
# Analyzed and saved panoptic segmentation for image 000047
# Processed image 000048
# Made panoptic segmentation for image 000048
# Analyzed and saved panoptic segmentation for image 000048
# Processed image 000049
# Made panoptic segmentation for image 000049
# Analyzed and saved panoptic segmentation for image 000049
# Processed image 000050
# Made panoptic segmentation for image 000050
# Analyzed and saved panoptic segmentation for image 000050
# Processed image 000051
# Made panoptic segmentation for image 000051
# Analyzed and saved panoptic segmentation for image 000051
# Processed image 000052
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000052
# Analyzed and saved panoptic segmentation for image 000052
# Processed image 000053
# Made panoptic segmentation for image 000053
# Analyzed and saved panoptic segmentation for image 000053
# Processed image 000054
# Made panoptic segmentation for image 000054
# Analyzed and saved panoptic segmentation for image 000054
# Processed image 000055
# Made panoptic segmentation for image 000055
# Analyzed and saved panoptic segmentation for image 000055
# Processed image 000056
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000056
# Analyzed and saved panoptic segmentation for image 000056
# Processed image 000057
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000057
# Analyzed and saved panoptic segmentation for image 000057
# Processed image 000058
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000058
# Analyzed and saved panoptic segmentation for image 000058
# Processed image 000059
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000059
# Analyzed and saved panoptic segmentation for image 000059
# Processed image 000060
# Made panoptic segmentation for image 000060
# Analyzed and saved panoptic segmentation for image 000060
# Processed image 000061
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000061
# Analyzed and saved panoptic segmentation for image 000061
# Processed image 000062
# Made panoptic segmentation for image 000062
# Analyzed and saved panoptic segmentation for image 000062
# Processed image 000063
# Found an object I am not trained to handle: 13
# Made panoptic segmentation for image 000063
# Analyzed and saved panoptic segmentation for image 000063
# Processed image 000064
# Made panoptic segmentation for image 000064
# Analyzed and saved panoptic segmentation for image 000064
# Processed image 000065
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000065
# Analyzed and saved panoptic segmentation for image 000065
# Processed image 000066
# Made panoptic segmentation for image 000066
# Analyzed and saved panoptic segmentation for image 000066
# Processed image 000067
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000067
# Analyzed and saved panoptic segmentation for image 000067
# Processed image 000068
# Found an object I am not trained to handle: 26
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000068
# Analyzed and saved panoptic segmentation for image 000068
# Processed image 000069
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000069
# Analyzed and saved panoptic segmentation for image 000069
# Processed image 000070
# Made panoptic segmentation for image 000070
# Analyzed and saved panoptic segmentation for image 000070
# Processed image 000071
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 9
# Made panoptic segmentation for image 000071
# Analyzed and saved panoptic segmentation for image 000071
# Processed image 000072
# Made panoptic segmentation for image 000072
# Analyzed and saved panoptic segmentation for image 000072
# Processed image 000073
# Made panoptic segmentation for image 000073
# Analyzed and saved panoptic segmentation for image 000073
# Processed image 000074
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000074
# Analyzed and saved panoptic segmentation for image 000074
# Processed image 000075
# Made panoptic segmentation for image 000075
# Analyzed and saved panoptic segmentation for image 000075
# Processed image 000076
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 57
# Made panoptic segmentation for image 000076
# Analyzed and saved panoptic segmentation for image 000076
# Processed image 000077
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000077
# Analyzed and saved panoptic segmentation for image 000077
# Processed image 000078
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000078
# Analyzed and saved panoptic segmentation for image 000078
# Processed image 000079
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000079
# Analyzed and saved panoptic segmentation for image 000079
# Processed image 000080
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000080
# Analyzed and saved panoptic segmentation for image 000080
# Processed image 000081
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000081
# Analyzed and saved panoptic segmentation for image 000081
# Processed image 000082
# Made panoptic segmentation for image 000082
# Analyzed and saved panoptic segmentation for image 000082
# Processed image 000083
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 25
# Found an object I am not trained to handle: 57
# Made panoptic segmentation for image 000083
# Analyzed and saved panoptic segmentation for image 000083
# Processed image 000084
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000084
# Analyzed and saved panoptic segmentation for image 000084
# Processed image 000085
# Found an object I am not trained to handle: 25
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 25
# Made panoptic segmentation for image 000085
# Analyzed and saved panoptic segmentation for image 000085
# Processed image 000086
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 25
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000086
# Analyzed and saved panoptic segmentation for image 000086
# Processed image 000087
# Made panoptic segmentation for image 000087
# Analyzed and saved panoptic segmentation for image 000087
# Processed image 000088
# Found an object I am not trained to handle: 25
# Made panoptic segmentation for image 000088
# Analyzed and saved panoptic segmentation for image 000088
# Processed image 000089
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000089
# Analyzed and saved panoptic segmentation for image 000089
# Processed image 000090
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000090
# Analyzed and saved panoptic segmentation for image 000090
# Processed image 000091
# Made panoptic segmentation for image 000091
# Analyzed and saved panoptic segmentation for image 000091
# Processed image 000092
# Made panoptic segmentation for image 000092
# Analyzed and saved panoptic segmentation for image 000092
# Processed image 000093
# Made panoptic segmentation for image 000093
# Analyzed and saved panoptic segmentation for image 000093
# Processed image 000094
# Made panoptic segmentation for image 000094
# Analyzed and saved panoptic segmentation for image 000094
# Processed image 000095
# Made panoptic segmentation for image 000095
# Analyzed and saved panoptic segmentation for image 000095
# Processed image 000096
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000096
# Analyzed and saved panoptic segmentation for image 000096
# Processed image 000097
# Found an object I am not trained to handle: 26
# Found an object I am not trained to handle: 26
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000097
# Analyzed and saved panoptic segmentation for image 000097
# Processed image 000098
# Found an object I am not trained to handle: 25
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000098
# Analyzed and saved panoptic segmentation for image 000098
# Processed image 000099
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000099
# Analyzed and saved panoptic segmentation for image 000099
# Processed image 000100
# Found an object I am not trained to handle: 25
# Made panoptic segmentation for image 000100
# Analyzed and saved panoptic segmentation for image 000100
# Processed image 000101
# Made panoptic segmentation for image 000101
# Analyzed and saved panoptic segmentation for image 000101
# Processed image 000102
# Made panoptic segmentation for image 000102
# Analyzed and saved panoptic segmentation for image 000102
# Processed image 000103
# Made panoptic segmentation for image 000103
# Analyzed and saved panoptic segmentation for image 000103
# Processed image 000104
# Made panoptic segmentation for image 000104
# Analyzed and saved panoptic segmentation for image 000104
# Processed image 000105
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000105
# Analyzed and saved panoptic segmentation for image 000105
# Processed image 000106
# Made panoptic segmentation for image 000106
# Analyzed and saved panoptic segmentation for image 000106
# Processed image 000107
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000107
# Analyzed and saved panoptic segmentation for image 000107
# Processed image 000108
# Made panoptic segmentation for image 000108
# Analyzed and saved panoptic segmentation for image 000108
# Processed image 000109
# Made panoptic segmentation for image 000109
# Analyzed and saved panoptic segmentation for image 000109
# Processed image 000110
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000110
# Analyzed and saved panoptic segmentation for image 000110
# Processed image 000111
# Found an object I am not trained to handle: 13
# Made panoptic segmentation for image 000111
# Analyzed and saved panoptic segmentation for image 000111
# Processed image 000112
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000112
# Analyzed and saved panoptic segmentation for image 000112
# Processed image 000113
# Made panoptic segmentation for image 000113
# Analyzed and saved panoptic segmentation for image 000113
# Processed image 000114
# Made panoptic segmentation for image 000114
# Analyzed and saved panoptic segmentation for image 000114
# Processed image 000115
# Found an object I am not trained to handle: 29
# Found an object I am not trained to handle: 25
# Found an object I am not trained to handle: 17
# Found an object I am not trained to handle: 25
# Made panoptic segmentation for image 000115
# Analyzed and saved panoptic segmentation for image 000115
# Processed image 000116
# Made panoptic segmentation for image 000116
# Analyzed and saved panoptic segmentation for image 000116
# Processed image 000117
# Made panoptic segmentation for image 000117
# Analyzed and saved panoptic segmentation for image 000117
# Processed image 000118
# Found an object I am not trained to handle: 39
# Made panoptic segmentation for image 000118
# Analyzed and saved panoptic segmentation for image 000118
# Processed image 000119
# Made panoptic segmentation for image 000119
# Analyzed and saved panoptic segmentation for image 000119
# Processed image 000120
# Made panoptic segmentation for image 000120
# Analyzed and saved panoptic segmentation for image 000120
# Processed image 000121
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000121
# Analyzed and saved panoptic segmentation for image 000121
# Processed image 000122
# Made panoptic segmentation for image 000122
# Analyzed and saved panoptic segmentation for image 000122
# Processed image 000123
# Made panoptic segmentation for image 000123
# Analyzed and saved panoptic segmentation for image 000123
# Processed image 000124
# Made panoptic segmentation for image 000124
# Analyzed and saved panoptic segmentation for image 000124
# Processed image 000125
# Made panoptic segmentation for image 000125
# Analyzed and saved panoptic segmentation for image 000125
# Processed image 000126
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000126
# Analyzed and saved panoptic segmentation for image 000126
# Processed image 000127
# Made panoptic segmentation for image 000127
# Analyzed and saved panoptic segmentation for image 000127
# Processed image 000128
# Made panoptic segmentation for image 000128
# Analyzed and saved panoptic segmentation for image 000128
# Processed image 000129
# Made panoptic segmentation for image 000129
# Analyzed and saved panoptic segmentation for image 000129
# Processed image 000130
# Made panoptic segmentation for image 000130
# Analyzed and saved panoptic segmentation for image 000130
# Processed image 000131
# Found an object I am not trained to handle: 14
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000131
# Analyzed and saved panoptic segmentation for image 000131
# Processed image 000132
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 57
# Made panoptic segmentation for image 000132
# Analyzed and saved panoptic segmentation for image 000132
# Processed image 000133
# Made panoptic segmentation for image 000133
# Analyzed and saved panoptic segmentation for image 000133
# Processed image 000134
# Made panoptic segmentation for image 000134
# Analyzed and saved panoptic segmentation for image 000134
# Processed image 000135
# Made panoptic segmentation for image 000135
# Analyzed and saved panoptic segmentation for image 000135
# Processed image 000136
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000136
# Analyzed and saved panoptic segmentation for image 000136
# Processed image 000137
# Made panoptic segmentation for image 000137
# Analyzed and saved panoptic segmentation for image 000137
# Processed image 000138
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000138
# Analyzed and saved panoptic segmentation for image 000138
# Processed image 000139
# Made panoptic segmentation for image 000139
# Analyzed and saved panoptic segmentation for image 000139
# Processed image 000140
# Found an object I am not trained to handle: 29
# Found an object I am not trained to handle: 29
# Found an object I am not trained to handle: 29
# Found an object I am not trained to handle: 29
# Made panoptic segmentation for image 000140
# Analyzed and saved panoptic segmentation for image 000140
# Processed image 000141
# Made panoptic segmentation for image 000141
# Analyzed and saved panoptic segmentation for image 000141
# Processed image 000142
# Made panoptic segmentation for image 000142
# Analyzed and saved panoptic segmentation for image 000142
# Processed image 000143
# Made panoptic segmentation for image 000143
# Analyzed and saved panoptic segmentation for image 000143
# Processed image 000144
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 25
# Made panoptic segmentation for image 000144
# Analyzed and saved panoptic segmentation for image 000144
# Processed image 000145
# Made panoptic segmentation for image 000145
# Analyzed and saved panoptic segmentation for image 000145
# Processed image 000146
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000146
# Analyzed and saved panoptic segmentation for image 000146
# Processed image 000147
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000147
# Analyzed and saved panoptic segmentation for image 000147
# Processed image 000148
# Made panoptic segmentation for image 000148
# Analyzed and saved panoptic segmentation for image 000148
# Processed image 000149
# Made panoptic segmentation for image 000149
# Analyzed and saved panoptic segmentation for image 000149
# Processed image 000150
# Made panoptic segmentation for image 000150
# Analyzed and saved panoptic segmentation for image 000150
# Processed image 000151
# Made panoptic segmentation for image 000151
# Analyzed and saved panoptic segmentation for image 000151
# Processed image 000152
# Made panoptic segmentation for image 000152
# Analyzed and saved panoptic segmentation for image 000152
# Processed image 000153
# Found an object I am not trained to handle: 75
# Made panoptic segmentation for image 000153
# Analyzed and saved panoptic segmentation for image 000153
# Processed image 000154
# Made panoptic segmentation for image 000154
# Analyzed and saved panoptic segmentation for image 000154
# Processed image 000155
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000155
# Analyzed and saved panoptic segmentation for image 000155
# Processed image 000156
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000156
# Analyzed and saved panoptic segmentation for image 000156
# Processed image 000157
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000157
# Analyzed and saved panoptic segmentation for image 000157
# Processed image 000158
# Made panoptic segmentation for image 000158
# Analyzed and saved panoptic segmentation for image 000158
# Processed image 000159
# Made panoptic segmentation for image 000159
# Analyzed and saved panoptic segmentation for image 000159
# Processed image 000160
# Made panoptic segmentation for image 000160
# Analyzed and saved panoptic segmentation for image 000160
# Processed image 000161
# Made panoptic segmentation for image 000161
# Analyzed and saved panoptic segmentation for image 000161
# Processed image 000162
# Made panoptic segmentation for image 000162
# Analyzed and saved panoptic segmentation for image 000162
# Processed image 000163
# Made panoptic segmentation for image 000163
# Analyzed and saved panoptic segmentation for image 000163
# Processed image 000164
# Found an object I am not trained to handle: 9
# Made panoptic segmentation for image 000164
# Analyzed and saved panoptic segmentation for image 000164
# Processed image 000165
# Made panoptic segmentation for image 000165
# Analyzed and saved panoptic segmentation for image 000165
# Processed image 000166
# Made panoptic segmentation for image 000166
# Analyzed and saved panoptic segmentation for image 000166
# Processed image 000167
# Made panoptic segmentation for image 000167
# Analyzed and saved panoptic segmentation for image 000167
# Processed image 000168
# Made panoptic segmentation for image 000168
# Analyzed and saved panoptic segmentation for image 000168
# Processed image 000169
# Made panoptic segmentation for image 000169
# Analyzed and saved panoptic segmentation for image 000169
# Processed image 000170
# Made panoptic segmentation for image 000170
# Analyzed and saved panoptic segmentation for image 000170
# Processed image 000171
# Made panoptic segmentation for image 000171
# Analyzed and saved panoptic segmentation for image 000171
# Processed image 000172
# Made panoptic segmentation for image 000172
# Analyzed and saved panoptic segmentation for image 000172
# Processed image 000173
# Made panoptic segmentation for image 000173
# Analyzed and saved panoptic segmentation for image 000173
# Processed image 000174
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 25
# Made panoptic segmentation for image 000174
# Analyzed and saved panoptic segmentation for image 000174
# Processed image 000175
# Found an object I am not trained to handle: 25
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000175
# Analyzed and saved panoptic segmentation for image 000175
# Processed image 000176
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000176
# Analyzed and saved panoptic segmentation for image 000176
# Processed image 000177
# Made panoptic segmentation for image 000177
# Analyzed and saved panoptic segmentation for image 000177
# Processed image 000178
# Made panoptic segmentation for image 000178
# Analyzed and saved panoptic segmentation for image 000178
# Processed image 000179
# Made panoptic segmentation for image 000179
# Analyzed and saved panoptic segmentation for image 000179
# Processed image 000180
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000180
# Analyzed and saved panoptic segmentation for image 000180
# Processed image 000181
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000181
# Analyzed and saved panoptic segmentation for image 000181
# Processed image 000182
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000182
# Analyzed and saved panoptic segmentation for image 000182
# Processed image 000183
# Made panoptic segmentation for image 000183
# Analyzed and saved panoptic segmentation for image 000183
# Processed image 000184
# Made panoptic segmentation for image 000184
# Analyzed and saved panoptic segmentation for image 000184
# Processed image 000185
# Made panoptic segmentation for image 000185
# Analyzed and saved panoptic segmentation for image 000185
# Processed image 000186
# Made panoptic segmentation for image 000186
# Analyzed and saved panoptic segmentation for image 000186
# Processed image 000187
# Made panoptic segmentation for image 000187
# Analyzed and saved panoptic segmentation for image 000187
# Processed image 000188
# Made panoptic segmentation for image 000188
# Analyzed and saved panoptic segmentation for image 000188
# Processed image 000189
# Made panoptic segmentation for image 000189
# Analyzed and saved panoptic segmentation for image 000189
# Processed image 000190
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000190
# Analyzed and saved panoptic segmentation for image 000190
# Processed image 000191
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000191
# Analyzed and saved panoptic segmentation for image 000191
# Processed image 000192
# Made panoptic segmentation for image 000192
# Analyzed and saved panoptic segmentation for image 000192
# Processed image 000193
# Made panoptic segmentation for image 000193
# Analyzed and saved panoptic segmentation for image 000193
# Processed image 000194
# Found an object I am not trained to handle: 37
# Made panoptic segmentation for image 000194
# Analyzed and saved panoptic segmentation for image 000194
# Processed image 000195
# Made panoptic segmentation for image 000195
# Analyzed and saved panoptic segmentation for image 000195
# Processed image 000196
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000196
# Analyzed and saved panoptic segmentation for image 000196
# Processed image 000197
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000197
# Analyzed and saved panoptic segmentation for image 000197
# Processed image 000198
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000198
# Analyzed and saved panoptic segmentation for image 000198
# Processed image 000199
# Made panoptic segmentation for image 000199
# Analyzed and saved panoptic segmentation for image 000199
# Processed image 000200
# Made panoptic segmentation for image 000200
# Analyzed and saved panoptic segmentation for image 000200
# Processed image 000201
# Made panoptic segmentation for image 000201
# Analyzed and saved panoptic segmentation for image 000201
# Processed image 000202
# Made panoptic segmentation for image 000202
# Analyzed and saved panoptic segmentation for image 000202
# Processed image 000203
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000203
# Analyzed and saved panoptic segmentation for image 000203
# Processed image 000204
# Found an object I am not trained to handle: 25
# Found an object I am not trained to handle: 25
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000204
# Analyzed and saved panoptic segmentation for image 000204
# Processed image 000205
# Made panoptic segmentation for image 000205
# Analyzed and saved panoptic segmentation for image 000205
# Processed image 000206
# Made panoptic segmentation for image 000206
# Analyzed and saved panoptic segmentation for image 000206
# Processed image 000207
# Made panoptic segmentation for image 000207
# Analyzed and saved panoptic segmentation for image 000207
# Processed image 000208
# Made panoptic segmentation for image 000208
# Analyzed and saved panoptic segmentation for image 000208
# Processed image 000209
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000209
# Analyzed and saved panoptic segmentation for image 000209
# Processed image 000210
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000210
# Analyzed and saved panoptic segmentation for image 000210
# Processed image 000211
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000211
# Analyzed and saved panoptic segmentation for image 000211
# Processed image 000212
# Made panoptic segmentation for image 000212
# Analyzed and saved panoptic segmentation for image 000212
# Processed image 000213
# Made panoptic segmentation for image 000213
# Analyzed and saved panoptic segmentation for image 000213
# Processed image 000214
# Made panoptic segmentation for image 000214
# Analyzed and saved panoptic segmentation for image 000214
# Processed image 000215
# Made panoptic segmentation for image 000215
# Analyzed and saved panoptic segmentation for image 000215
# Processed image 000216
# Made panoptic segmentation for image 000216
# Analyzed and saved panoptic segmentation for image 000216
# Processed image 000217
# Made panoptic segmentation for image 000217
# Analyzed and saved panoptic segmentation for image 000217
# Processed image 000218
# Made panoptic segmentation for image 000218
# Analyzed and saved panoptic segmentation for image 000218
# Processed image 000219
# Made panoptic segmentation for image 000219
# Analyzed and saved panoptic segmentation for image 000219
# Processed image 000220
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000220
# Analyzed and saved panoptic segmentation for image 000220
# Processed image 000221
# Made panoptic segmentation for image 000221
# Analyzed and saved panoptic segmentation for image 000221
# Processed image 000222
# Made panoptic segmentation for image 000222
# Analyzed and saved panoptic segmentation for image 000222
# Processed image 000223
# Made panoptic segmentation for image 000223
# Analyzed and saved panoptic segmentation for image 000223
# Processed image 000224
# Made panoptic segmentation for image 000224
# Analyzed and saved panoptic segmentation for image 000224
# Processed image 000225
# Made panoptic segmentation for image 000225
# Analyzed and saved panoptic segmentation for image 000225
# Processed image 000226
# Made panoptic segmentation for image 000226
# Analyzed and saved panoptic segmentation for image 000226
# Processed image 000227
# Found an object I am not trained to handle: 25
# Found an object I am not trained to handle: 14
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000227
# Analyzed and saved panoptic segmentation for image 000227
# Processed image 000228
# Made panoptic segmentation for image 000228
# Analyzed and saved panoptic segmentation for image 000228
# Processed image 000229
# Found an object I am not trained to handle: 18
# Made panoptic segmentation for image 000229
# Analyzed and saved panoptic segmentation for image 000229
# Processed image 000230
# Made panoptic segmentation for image 000230
# Analyzed and saved panoptic segmentation for image 000230
# Processed image 000231
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000231
# Analyzed and saved panoptic segmentation for image 000231
# Processed image 000232
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000232
# Analyzed and saved panoptic segmentation for image 000232
# Processed image 000233
# Made panoptic segmentation for image 000233
# Analyzed and saved panoptic segmentation for image 000233
# Processed image 000234
# Made panoptic segmentation for image 000234
# Analyzed and saved panoptic segmentation for image 000234
# Processed image 000235
# Made panoptic segmentation for image 000235
# Analyzed and saved panoptic segmentation for image 000235
# Processed image 000236
# Made panoptic segmentation for image 000236
# Analyzed and saved panoptic segmentation for image 000236
# Processed image 000237
# Made panoptic segmentation for image 000237
# Analyzed and saved panoptic segmentation for image 000237
# Processed image 000238
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000238
# Analyzed and saved panoptic segmentation for image 000238
# Processed image 000239
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000239
# Analyzed and saved panoptic segmentation for image 000239
# Processed image 000240
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000240
# Analyzed and saved panoptic segmentation for image 000240
# Processed image 000241
# Made panoptic segmentation for image 000241
# Analyzed and saved panoptic segmentation for image 000241
# Processed image 000242
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000242
# Analyzed and saved panoptic segmentation for image 000242
# Processed image 000243
# Made panoptic segmentation for image 000243
# Analyzed and saved panoptic segmentation for image 000243
# Processed image 000244
# Made panoptic segmentation for image 000244
# Analyzed and saved panoptic segmentation for image 000244
# Processed image 000245
# Made panoptic segmentation for image 000245
# Analyzed and saved panoptic segmentation for image 000245
# Processed image 000246
# Made panoptic segmentation for image 000246
# Analyzed and saved panoptic segmentation for image 000246
# Processed image 000247
# Found an object I am not trained to handle: 17
# Made panoptic segmentation for image 000247
# Analyzed and saved panoptic segmentation for image 000247
# Processed image 000248
# Made panoptic segmentation for image 000248
# Analyzed and saved panoptic segmentation for image 000248
# Processed image 000249
# Made panoptic segmentation for image 000249
# Analyzed and saved panoptic segmentation for image 000249
# Processed image 000250
# Made panoptic segmentation for image 000250
# Analyzed and saved panoptic segmentation for image 000250
# Processed image 000251
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000251
# Analyzed and saved panoptic segmentation for image 000251
# Processed image 000252
# Made panoptic segmentation for image 000252
# Analyzed and saved panoptic segmentation for image 000252
# Processed image 000253
# Made panoptic segmentation for image 000253
# Analyzed and saved panoptic segmentation for image 000253
# Processed image 000254
# Made panoptic segmentation for image 000254
# Analyzed and saved panoptic segmentation for image 000254
# Processed image 000255
# Made panoptic segmentation for image 000255
# Analyzed and saved panoptic segmentation for image 000255
# Processed image 000256
# Found an object I am not trained to handle: 29
# Found an object I am not trained to handle: 27
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000256
# Analyzed and saved panoptic segmentation for image 000256
# Processed image 000257
# Found an object I am not trained to handle: 14
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000257
# Analyzed and saved panoptic segmentation for image 000257
# Processed image 000258
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000258
# Analyzed and saved panoptic segmentation for image 000258
# Processed image 000259
# Made panoptic segmentation for image 000259
# Analyzed and saved panoptic segmentation for image 000259
# Processed image 000260
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000260
# Analyzed and saved panoptic segmentation for image 000260
# Processed image 000261
# Made panoptic segmentation for image 000261
# Analyzed and saved panoptic segmentation for image 000261
# Processed image 000262
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000262
# Analyzed and saved panoptic segmentation for image 000262
# Processed image 000263
# Made panoptic segmentation for image 000263
# Analyzed and saved panoptic segmentation for image 000263
# Processed image 000264
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000264
# Analyzed and saved panoptic segmentation for image 000264
# Processed image 000265
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000265
# Analyzed and saved panoptic segmentation for image 000265
# Processed image 000266
# Made panoptic segmentation for image 000266
# Analyzed and saved panoptic segmentation for image 000266
# Processed image 000267
# Made panoptic segmentation for image 000267
# Analyzed and saved panoptic segmentation for image 000267
# Processed image 000268
# Made panoptic segmentation for image 000268
# Analyzed and saved panoptic segmentation for image 000268
# Processed image 000269
# Made panoptic segmentation for image 000269
# Analyzed and saved panoptic segmentation for image 000269
# Processed image 000270
# Made panoptic segmentation for image 000270
# Analyzed and saved panoptic segmentation for image 000270
# Processed image 000271
# Found an object I am not trained to handle: 14
# Made panoptic segmentation for image 000271
# Analyzed and saved panoptic segmentation for image 000271
# Processed image 000272
# Made panoptic segmentation for image 000272
# Analyzed and saved panoptic segmentation for image 000272
# Processed image 000273
# Made panoptic segmentation for image 000273
# Analyzed and saved panoptic segmentation for image 000273
# Processed image 000274
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000274
# Analyzed and saved panoptic segmentation for image 000274
# Processed image 000275
# Made panoptic segmentation for image 000275
# Analyzed and saved panoptic segmentation for image 000275
# Processed image 000276
# Made panoptic segmentation for image 000276
# Analyzed and saved panoptic segmentation for image 000276
# Processed image 000277
# Made panoptic segmentation for image 000277
# Analyzed and saved panoptic segmentation for image 000277
# Processed image 000278
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000278
# Analyzed and saved panoptic segmentation for image 000278
# Processed image 000279
# Made panoptic segmentation for image 000279
# Analyzed and saved panoptic segmentation for image 000279
# Processed image 000280
# Made panoptic segmentation for image 000280
# Analyzed and saved panoptic segmentation for image 000280
# Processed image 000281
# Made panoptic segmentation for image 000281
# Analyzed and saved panoptic segmentation for image 000281
# Processed image 000282
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000282
# Analyzed and saved panoptic segmentation for image 000282
# Processed image 000283
# Made panoptic segmentation for image 000283
# Analyzed and saved panoptic segmentation for image 000283
# Processed image 000284
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000284
# Analyzed and saved panoptic segmentation for image 000284
# Processed image 000285
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 57
# Made panoptic segmentation for image 000285
# Analyzed and saved panoptic segmentation for image 000285
# Processed image 000286
# Found an object I am not trained to handle: 57
# Made panoptic segmentation for image 000286
# Analyzed and saved panoptic segmentation for image 000286
# Processed image 000287
# Made panoptic segmentation for image 000287
# Analyzed and saved panoptic segmentation for image 000287
# Processed image 000288
# Made panoptic segmentation for image 000288
# Analyzed and saved panoptic segmentation for image 000288
# Processed image 000289
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000289
# Analyzed and saved panoptic segmentation for image 000289
# Processed image 000290
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 73
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000290
# Analyzed and saved panoptic segmentation for image 000290
# Processed image 000291
# Made panoptic segmentation for image 000291
# Analyzed and saved panoptic segmentation for image 000291
# Processed image 000292
# Made panoptic segmentation for image 000292
# Analyzed and saved panoptic segmentation for image 000292
# Processed image 000293
# Made panoptic segmentation for image 000293
# Analyzed and saved panoptic segmentation for image 000293
# Processed image 000294
# Made panoptic segmentation for image 000294
# Analyzed and saved panoptic segmentation for image 000294
# Processed image 000295
# Made panoptic segmentation for image 000295
# Analyzed and saved panoptic segmentation for image 000295
# Processed image 000296
# Made panoptic segmentation for image 000296
# Analyzed and saved panoptic segmentation for image 000296
# Processed image 000297
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000297
# Analyzed and saved panoptic segmentation for image 000297
# Processed image 000298
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000298
# Analyzed and saved panoptic segmentation for image 000298
# Processed image 000299
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000299
# Analyzed and saved panoptic segmentation for image 000299
# Processed image 000300
# Made panoptic segmentation for image 000300
# Analyzed and saved panoptic segmentation for image 000300
# Processed image 000301
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 57
# Made panoptic segmentation for image 000301
# Analyzed and saved panoptic segmentation for image 000301
# Processed image 000302
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000302
# Analyzed and saved panoptic segmentation for image 000302
# Processed image 000303
# Made panoptic segmentation for image 000303
# Analyzed and saved panoptic segmentation for image 000303
# Processed image 000304
# Found an object I am not trained to handle: 59
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000304
# Analyzed and saved panoptic segmentation for image 000304
# Processed image 000305
# Made panoptic segmentation for image 000305
# ...
# Analyzed and saved panoptic segmentation for image 000385
# Processed image 000386
# Made panoptic segmentation for image 000386
# Analyzed and saved panoptic segmentation for image 000386
# Processed image 000387
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000387
# Analyzed and saved panoptic segmentation for image 000387
# Processed image 000388
# Made panoptic segmentation for image 000388
# Analyzed and saved panoptic segmentation for image 000388
# Processed image 000389
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000389
# Analyzed and saved panoptic segmentation for image 000389
# Processed image 000390
# Made panoptic segmentation for image 000390
# Analyzed and saved panoptic segmentation for image 000390
# Processed image 000391
# Made panoptic segmentation for image 000391
# Analyzed and saved panoptic segmentation for image 000391
# Processed image 000392
# Made panoptic segmentation for image 000392
# Analyzed and saved panoptic segmentation for image 000392
# Processed image 000393
# Made panoptic segmentation for image 000393
# Analyzed and saved panoptic segmentation for image 000393
# Processed image 000394
# Made panoptic segmentation for image 000394
# Analyzed and saved panoptic segmentation for image 000394
# Processed image 000395
# Made panoptic segmentation for image 000395
# Analyzed and saved panoptic segmentation for image 000395
# Processed image 000396
# Made panoptic segmentation for image 000396
# Analyzed and saved panoptic segmentation for image 000396
# Processed image 000397
# Made panoptic segmentation for image 000397
# Analyzed and saved panoptic segmentation for image 000397
# Processed image 000398
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000398
# Analyzed and saved panoptic segmentation for image 000398
# Processed image 000399
# Made panoptic segmentation for image 000399
# Analyzed and saved panoptic segmentation for image 000399
# Processed image 000400
# Made panoptic segmentation for image 000400
# Analyzed and saved panoptic segmentation for image 000400
# Processed image 000401
# Made panoptic segmentation for image 000401
# Analyzed and saved panoptic segmentation for image 000401
# Processed image 000402
# Made panoptic segmentation for image 000402
# Analyzed and saved panoptic segmentation for image 000402
# Processed image 000403
# Made panoptic segmentation for image 000403
# Analyzed and saved panoptic segmentation for image 000403
# Processed image 000404
# Made panoptic segmentation for image 000404
# Analyzed and saved panoptic segmentation for image 000404
# Processed image 000405
# Made panoptic segmentation for image 000405
# Analyzed and saved panoptic segmentation for image 000405
# Processed image 000406
# Made panoptic segmentation for image 000406
# Analyzed and saved panoptic segmentation for image 000406
# Processed image 000407
# Made panoptic segmentation for image 000407
# Analyzed and saved panoptic segmentation for image 000407
# Processed image 000408
# Made panoptic segmentation for image 000408
# Analyzed and saved panoptic segmentation for image 000408
# Processed image 000409
# Made panoptic segmentation for image 000409
# Analyzed and saved panoptic segmentation for image 000409
# Processed image 000410
# Made panoptic segmentation for image 000410
# Analyzed and saved panoptic segmentation for image 000410
# Processed image 000411
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000411
# Analyzed and saved panoptic segmentation for image 000411
# Processed image 000412
# Made panoptic segmentation for image 000412
# Analyzed and saved panoptic segmentation for image 000412
# Processed image 000413
# Made panoptic segmentation for image 000413
# Analyzed and saved panoptic segmentation for image 000413
# Processed image 000414
# Made panoptic segmentation for image 000414
# Analyzed and saved panoptic segmentation for image 000414
# Processed image 000415
# Found an object I am not trained to handle: 25
# Made panoptic segmentation for image 000415
# Analyzed and saved panoptic segmentation for image 000415
# Processed image 000416
# Made panoptic segmentation for image 000416
# Analyzed and saved panoptic segmentation for image 000416
# Processed image 000417
# Made panoptic segmentation for image 000417
# Analyzed and saved panoptic segmentation for image 000417
# Processed image 000418
# Made panoptic segmentation for image 000418
# Analyzed and saved panoptic segmentation for image 000418
# Processed image 000419
# Made panoptic segmentation for image 000419
# Analyzed and saved panoptic segmentation for image 000419
# Processed image 000420
# Made panoptic segmentation for image 000420
# Analyzed and saved panoptic segmentation for image 000420
# Processed image 000421
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000421
# Analyzed and saved panoptic segmentation for image 000421
# Processed image 000422
# Made panoptic segmentation for image 000422
# Analyzed and saved panoptic segmentation for image 000422
# Processed image 000423
# Made panoptic segmentation for image 000423
# Analyzed and saved panoptic segmentation for image 000423
# Processed image 000424
# Made panoptic segmentation for image 000424
# Analyzed and saved panoptic segmentation for image 000424
# Processed image 000425
# Made panoptic segmentation for image 000425
# Analyzed and saved panoptic segmentation for image 000425
# Processed image 000426
# Made panoptic segmentation for image 000426
# Analyzed and saved panoptic segmentation for image 000426
# Processed image 000427
# Made panoptic segmentation for image 000427
# Analyzed and saved panoptic segmentation for image 000427
# Processed image 000428
# Found an object I am not trained to handle: 25
# Made panoptic segmentation for image 000428
# Analyzed and saved panoptic segmentation for image 000428
# Processed image 000429
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000429
# Analyzed and saved panoptic segmentation for image 000429
# Processed image 000430
# Made panoptic segmentation for image 000430
# Analyzed and saved panoptic segmentation for image 000430
# Processed image 000431
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000431
# Analyzed and saved panoptic segmentation for image 000431
# Processed image 000432
# Made panoptic segmentation for image 000432
# Analyzed and saved panoptic segmentation for image 000432
# Processed image 000433
# Made panoptic segmentation for image 000433
# Analyzed and saved panoptic segmentation for image 000433
# Processed image 000434
# Made panoptic segmentation for image 000434
# Analyzed and saved panoptic segmentation for image 000434
# Processed image 000435
# Made panoptic segmentation for image 000435
# Analyzed and saved panoptic segmentation for image 000435
# Processed image 000436
# Made panoptic segmentation for image 000436
# Analyzed and saved panoptic segmentation for image 000436
# Processed image 000437
# Made panoptic segmentation for image 000437
# Analyzed and saved panoptic segmentation for image 000437
# Processed image 000438
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000438
# Analyzed and saved panoptic segmentation for image 000438
# Processed image 000439
# Made panoptic segmentation for image 000439
# Analyzed and saved panoptic segmentation for image 000439
# Processed image 000440
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000440
# Analyzed and saved panoptic segmentation for image 000440
# Processed image 000441
# Made panoptic segmentation for image 000441
# Analyzed and saved panoptic segmentation for image 000441
# Processed image 000442
# Made panoptic segmentation for image 000442
# Analyzed and saved panoptic segmentation for image 000442
# Processed image 000443
# Made panoptic segmentation for image 000443
# Analyzed and saved panoptic segmentation for image 000443
# Processed image 000444
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000444
# Analyzed and saved panoptic segmentation for image 000444
# Processed image 000445
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000445
# Analyzed and saved panoptic segmentation for image 000445
# Processed image 000446
# Made panoptic segmentation for image 000446
# Analyzed and saved panoptic segmentation for image 000446
# Processed image 000447
# Made panoptic segmentation for image 000447
# Analyzed and saved panoptic segmentation for image 000447
# Processed image 000448
# Made panoptic segmentation for image 000448
# Analyzed and saved panoptic segmentation for image 000448
# Processed image 000449
# Made panoptic segmentation for image 000449
# Analyzed and saved panoptic segmentation for image 000449
# Processed image 000450
# Made panoptic segmentation for image 000450
# Analyzed and saved panoptic segmentation for image 000450
# Processed image 000451
# Made panoptic segmentation for image 000451
# Analyzed and saved panoptic segmentation for image 000451
# Processed image 000452
# Made panoptic segmentation for image 000452
# Analyzed and saved panoptic segmentation for image 000452
# Processed image 000453
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000453
# Analyzed and saved panoptic segmentation for image 000453
# Processed image 000454
# Made panoptic segmentation for image 000454
# Analyzed and saved panoptic segmentation for image 000454
# Processed image 000455
# Made panoptic segmentation for image 000455
# Analyzed and saved panoptic segmentation for image 000455
# Processed image 000456
# Made panoptic segmentation for image 000456
# Analyzed and saved panoptic segmentation for image 000456
# Processed image 000457
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000457
# Analyzed and saved panoptic segmentation for image 000457
# Processed image 000458
# Made panoptic segmentation for image 000458
# Analyzed and saved panoptic segmentation for image 000458
# Processed image 000459
# Made panoptic segmentation for image 000459
# Analyzed and saved panoptic segmentation for image 000459
# Processed image 000460
# Made panoptic segmentation for image 000460
# Analyzed and saved panoptic segmentation for image 000460
# Processed image 000461
# Made panoptic segmentation for image 000461
# Analyzed and saved panoptic segmentation for image 000461
# Processed image 000462
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000462
# Analyzed and saved panoptic segmentation for image 000462
# Processed image 000463
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000463
# Analyzed and saved panoptic segmentation for image 000463
# Processed image 000464
# Made panoptic segmentation for image 000464
# Analyzed and saved panoptic segmentation for image 000464
# Processed image 000465
# Made panoptic segmentation for image 000465
# Analyzed and saved panoptic segmentation for image 000465
# Processed image 000466
# Made panoptic segmentation for image 000466
# Analyzed and saved panoptic segmentation for image 000466
# Processed image 000467
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000467
# Analyzed and saved panoptic segmentation for image 000467
# Processed image 000468
# Found an object I am not trained to handle: 18
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000468
# Analyzed and saved panoptic segmentation for image 000468
# Processed image 000469
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000469
# Analyzed and saved panoptic segmentation for image 000469
# Processed image 000470
# Found an object I am not trained to handle: 26
# Made panoptic segmentation for image 000470
# Analyzed and saved panoptic segmentation for image 000470
# Processed image 000471
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 57
# Found an object I am not trained to handle: 57
# Made panoptic segmentation for image 000471
# Analyzed and saved panoptic segmentation for image 000471
# Processed image 000472
# Made panoptic segmentation for image 000472
# Analyzed and saved panoptic segmentation for image 000472
# Processed image 000473
# Made panoptic segmentation for image 000473
# Analyzed and saved panoptic segmentation for image 000473
# Processed image 000474
# Found an object I am not trained to handle: 14
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000474
# Analyzed and saved panoptic segmentation for image 000474
# Processed image 000475
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000475
# Analyzed and saved panoptic segmentation for image 000475
# Processed image 000476
# Made panoptic segmentation for image 000476
# Analyzed and saved panoptic segmentation for image 000476
# Processed image 000477
# Made panoptic segmentation for image 000477
# Analyzed and saved panoptic segmentation for image 000477
# Processed image 000478
# Made panoptic segmentation for image 000478
# Analyzed and saved panoptic segmentation for image 000478
# Processed image 000479
# Made panoptic segmentation for image 000479
# Analyzed and saved panoptic segmentation for image 000479
# Processed image 000480
# Found an object I am not trained to handle: 59
# Made panoptic segmentation for image 000480
# Analyzed and saved panoptic segmentation for image 000480
# Processed image 000481
# Made panoptic segmentation for image 000481
# Analyzed and saved panoptic segmentation for image 000481
# Processed image 000482
# Made panoptic segmentation for image 000482
# Analyzed and saved panoptic segmentation for image 000482
# Processed image 000483
# Made panoptic segmentation for image 000483
# Analyzed and saved panoptic segmentation for image 000483
# Processed image 000484
# Made panoptic segmentation for image 000484
# Analyzed and saved panoptic segmentation for image 000484
# Processed image 000485
# Found an object I am not trained to handle: 11
# Made panoptic segmentation for image 000485
# Analyzed and saved panoptic segmentation for image 000485
# Processed image 000486
# Made panoptic segmentation for image 000486
# Analyzed and saved panoptic segmentation for image 000486
# Processed image 000487
# Made panoptic segmentation for image 000487
# Analyzed and saved panoptic segmentation for image 000487
# Processed image 000488
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000488
# Analyzed and saved panoptic segmentation for image 000488
# Processed image 000489
# Made panoptic segmentation for image 000489
# Analyzed and saved panoptic segmentation for image 000489
# Processed image 000490
# Made panoptic segmentation for image 000490
# Analyzed and saved panoptic segmentation for image 000490
# Processed image 000491
# Made panoptic segmentation for image 000491
# Analyzed and saved panoptic segmentation for image 000491
# Processed image 000492
# Found an object I am not trained to handle: 12
# Found an object I am not trained to handle: 12
# Made panoptic segmentation for image 000492
# Analyzed and saved panoptic segmentation for image 000492
# Processed image 000493
# Found an object I am not trained to handle: 27
# Made panoptic segmentation for image 000493
# Analyzed and saved panoptic segmentation for image 000493
# Processed image 000494
# Made panoptic segmentation for image 000494
# Analyzed and saved panoptic segmentation for image 000494
# Processed image 000495
# Made panoptic segmentation for image 000495
# Analyzed and saved panoptic segmentation for image 000495
# Processed image 000496
# Made panoptic segmentation for image 000496
# Analyzed and saved panoptic segmentation for image 000496
# Processed image 000497
# Found an object I am not trained to handle: 11
# Made panoptic segmentation for image 000497
# Analyzed and saved panoptic segmentation for image 000497
# Processed image 000498
# Made panoptic segmentation for image 000498
# Analyzed and saved panoptic segmentation for image 000498
# Processed image 000499
# Made panoptic segmentation for image 000499
# Analyzed and saved panoptic segmentation for image 000499

# %% [markdown]
# ## Calculate average values of panoptic, segmentation and recognition quality metrics

# %%
print(np.average(pq), np.average(sq), np.average(rq))
# Out:
# 0.580351830122578 0.7875140499247384 0.7372931654369143
